# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# https://www.kaggle.com/datasets/dinaouahbi/churndatacsv
df = pd.read_csv('./../data/Churndata.csv')

# %%
df.corr()
# Out:
#             tenure       age   address    income        ed    employ  \
# tenure    1.000000  0.431802  0.456328  0.109383 -0.070503  0.445755
# age       0.431802  1.000000  0.746566  0.211275 -0.071509  0.622553
# address   0.456328  0.746566  1.000000  0.132807 -0.145550  0.520926
# income    0.109383  0.211275  0.132807  1.000000  0.141241  0.345161
# ed       -0.070503 -0.071509 -0.145550  0.141241  1.000000 -0.213886
# employ    0.445755  0.622553  0.520926  0.345161 -0.213886  1.000000
# equip    -0.117102 -0.071357 -0.148977 -0.010741  0.488041 -0.174470
# callcard  0.426530  0.170404  0.209204 -0.019969 -0.071178  0.266612
# wireless -0.070590 -0.065527 -0.146478 -0.029635  0.267670 -0.101187
# longmon   0.763134  0.373547  0.421782  0.041808 -0.072735  0.363386
# tollmon   0.100214  0.053595 -0.015564 -0.003701 -0.000712  0.117962
# equipmon -0.043274 -0.030402 -0.125212  0.000275  0.492999 -0.141651
# cardmon   0.489857  0.203202  0.297395 -0.013513 -0.070990  0.219413
# ...

# %%
df = df[['tenure', 'age', 'address', 'ed', 'employ', 'equip', 'longmon', 'churn']]
df['churn'] = df['churn'].astype('int')
df
# Out:
#      tenure   age  address   ed  employ  equip  longmon  churn
# 0      11.0  33.0      7.0  5.0     5.0    0.0     4.40      1
# 1      33.0  33.0     12.0  2.0     0.0    0.0     9.45      1
# 2      23.0  30.0      9.0  1.0     2.0    0.0     6.30      0
# 3      38.0  35.0      5.0  2.0    10.0    1.0     6.05      0
# 4       7.0  35.0     14.0  2.0    15.0    0.0     7.10      0
# ..      ...   ...      ...  ...     ...    ...      ...    ...
# 195    55.0  44.0     24.0  1.0    23.0    0.0    17.35      0
# 196    34.0  23.0      3.0  1.0     7.0    0.0     6.00      0
# 197     6.0  32.0     10.0  1.0    10.0    0.0     3.85      0
# 198    24.0  30.0      0.0  4.0     5.0    0.0     8.70      1
# 199    61.0  50.0     16.0  2.0    22.0    1.0    16.85      0
#
# [200 rows x 8 columns]

# %%
X = df[['tenure', 'age', 'address', 'ed', 'employ', 'equip', 'longmon']].values
y = df['churn'].values

# %%
# learn faster, improve accuracy
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2, random_state=24)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
y_pred[:10]
# Out:
# array([0, 0, 1, 0, 0, 0, 1, 0, 1, 0])

# %%
y_pred_proba = model.predict_proba(X_test)
y_pred_proba[:10]
# Out:
# array([[0.68649046, 0.31350954],
#        [0.79244817, 0.20755183],
#        [0.35590493, 0.64409507],
#        [0.97495874, 0.02504126],
#        [0.98729719, 0.01270281],
#        [0.77208667, 0.22791333],
#        [0.36690087, 0.63309913],
#        [0.97322015, 0.02677985],
#        [0.49160663, 0.50839337],
#        [0.91880605, 0.08119395]])

# %%
from sklearn.metrics import log_loss, accuracy_score, recall_score, precision_score, f1_score, classification_report, confusion_matrix

print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))
print('Log Loss: ', log_loss(y_test, y_pred_proba))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:  0.725
# Recall:  0.625
# Precision:  0.38461538461538464
# F1 Score:  0.47619047619047616
# Log Loss:  0.4662825399951257
#               precision    recall  f1-score   support
#
#            0       0.89      0.75      0.81        32
#            1       0.38      0.62      0.48         8
#
#     accuracy                           0.72        40
#    macro avg       0.64      0.69      0.64        40
# weighted avg       0.79      0.72      0.75        40

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
# Out:
# <Axes: >
